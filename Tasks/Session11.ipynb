# %%
import time

from jedi.api import file_name

from SKEssentials.Main.Classes import display_ETime
t = time.time()
print("\033[37m" + display_ETime(time.time() - t) + "\033[0m")
# Out:
# 42.67692565917969 μs

# %%
# Sample Code
t = time.time()
for i in reversed(range(5)):
    print(i)
print("\033[37m" + display_ETime(time.time() - t) + "\033[0m")
# Out:
# 4
# 3
# 2
# 1
# 0
# 563.1446838378906 μs

# %%
t = time.time()

def remove_suffix(string, suffix):
    if string[-len(suffix):] == suffix:
        return string[:-len(suffix)]
    else: return string
def remove_prefix(string, prefix):
    if string[:len(prefix)] == prefix:
        return string[len(prefix):]
    else: return string

print(remove_prefix("mpkpk", "m"))

print("\033[37m" + display_ETime(time.time() - t) + "\033[0m")
# Out:
# pkpk
# 265.1214599609375 μs

# %%
t = time.time()

def parse_shebang(file_name):
    handle = open(file_name, "r")
    result = handle.read().split("\n")[0]
    return result
    if result[:2] == "#!":
        handle.close()
        result = remove_prefix(result, "#!")
        while result[0] == " ":
            result = remove_prefix(result, " ")
    else: return None
    handle.close()
    return result

print("\033[37m" + display_ETime(time.time() - t) + "\033[0m")
# Out:
# 117.54035949707031 μs

# %%
handle = open("C:/Users/ASUS/PycharmProjects/Project-1/SKEssentials/Main/MainII.py")
result = handle.read()
handle.close()

print(result)
# Out:
# def is_iterable(obj):
#     try:
#         list(obj)
#         return True
#     except TypeError:
#         return False
#
# def is_list_or_tuple(obj):
#     if type(obj) in (str, set, dict):
#         return False
#     else:
#         try:
#             list(obj)
#             return True
#         except TypeError:
#             return False
